# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

x = [
        10,
        30,
        50,
        100,
        1000,
        100000,
        1000000,
        10000000
    ]

y = [
        0,
        0.018000,
        0.003000,
        0.007000,
        0.060000,
        6.021000,
        59.564000,
        609.372000
    ]

y2 =[
        0.002000,
        0.001000,
        0.000000,
        0.003000,
        0.019000,
        1.695000,
        17.703000,
        164.058000
    ]

# plot
fig, ax = plt.subplots()

ax.plot(x, y, color="blue", linewidth=2, label="sequencial")
ax.plot(x, y2, color="red", linewidth=2, label="paralelo")

ax.set_xscale("log")
ax.legend()

plt.show()
